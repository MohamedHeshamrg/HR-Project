# %% [markdown]
#  **What Business Domain Does This Serve?
# This is clearly from a corporate HR analytics system, supporting:**
#
# 👨‍💼 Workforce Planning
#
# 💰 Compensation & Salary Strategy
#
# 🚀 Promotion Path & Talent Development
#
# 🏢 Departmental Allocation
#
# 🧑‍⚖️ Manager Effectiveness
#
# 📊 Gender Equity and Diversity Monitoring

# %% [markdown]
# ## Employee Data

# %%
import pandas as pd

dfE = pd.read_csv("employee.csv")
dfE.head()
# Out:
#       id  birth_date first_name last_name gender   hire_date
# 0  10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1  10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2  10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3  10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4  10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
dfE = dfE.rename(columns={'id': 'department_id'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dfE = dfD.rename(columns={'id': 'department_id'})
#
# NameError: name 'dfD' is not defined

# %%
# 1. Describe (categorical data)
print(dfE.describe(include='object'))
print()

# 2. Info
print()
print(dfE.info())

# 3. Null values
print()
print(dfE.isnull().sum())

# 4. Duplicates
print()
print(f"Duplicate rows: {dfE.duplicated().sum()}")

# 5. Data Validation
print()
print(f"Unique first names: {dfE['first_name'].nunique()}")
print(f"Unique last names: {dfE['last_name'].nunique()}")
# Out:
#        department_id         dept_name
# count              9                 9
# unique             9                 9
# top             d009  Customer Service
# freq               1                 1
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  9 non-null      object
#  1   dept_name      9 non-null      object
# dtypes: object(2)
# memory usage: 276.0+ bytes
# None
#
# department_id    0
# dept_name        0
# dtype: int64
#
# Duplicate rows: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 19
#      17 # 5. Data Validation
#      18 print()
# ---> 19 print(f"Unique first names: {dfE['first_name'].nunique()}")
#      20 print(f"Unique last names: {dfE['last_name'].nunique()}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'first_name'

# %% [markdown]
# ## Dep_Employee

# %%
import pandas as pd

dfDE = pd.read_csv("department_employee.csv")
dfDE.head()
# Out:
#    employee_id department_id   from_date     to_date
# 0        10001          d005  1986-06-26  9999-01-01
# 1        10002          d007  1996-08-03  9999-01-01
# 2        10003          d004  1995-12-03  9999-01-01
# 3        10004          d004  1986-12-01  9999-01-01
# 4        10005          d003  1989-09-12  9999-01-01

# %%
# 1. Describe (categorical data)
print(dfDE.describe(include='object'))

# 2. Info
print(dfDE.info())

# 3. Null values
print(dfDE.isnull().sum())

# 4. Duplicates
print(f"Duplicate rows: {dfDE.duplicated().sum()}")

# 5. Data Validation
print(f"Unique departments: {dfDE['department_id'].nunique()}")
print(f"Unique employees: {dfDE['employee_id'].nunique()}")
# Out:
#        department_id   from_date     to_date
# count         331603      331603      331603
# unique             9        6393        6085
# top             d005  1990-12-28  9999-01-01
# freq           85707          91      240124
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331603 entries, 0 to 331602
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   employee_id    331603 non-null  int64
#  1   department_id  331603 non-null  object
#  2   from_date      331603 non-null  object
#  3   to_date        331603 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 10.1+ MB
# None
# employee_id      0
# department_id    0
# from_date        0
# to_date          0
# dtype: int64
# Duplicate rows: 0
# Unique departments: 9
# Unique employees: 300024

# %% [markdown]
# ## Dep Data

# %%
import pandas as pd

dfD = pd.read_csv("department.csv")
dfD.head()
# Out:
#      id         dept_name
# 0  d009  Customer Service
# 1  d005       Development
# 2  d002           Finance
# 3  d003   Human Resources
# 4  d001         Marketing

# %%
dfD = dfD.rename(columns={'id': 'department_id'})

# %%
# 1. Describe (categorical data)
print(dfD.describe(include='object'))

# 2. Info
print(dfD.info())

# 3. Null values
print(dfD.isnull().sum())

# 4. Duplicates
print(f"Duplicate rows: {dfD.duplicated().sum()}")

# 5. Data Validation
print(f"Unique departments: {dfD['dept_name'].nunique()}")
# Out:
#           id         dept_name
# count      9                 9
# unique     9                 9
# top     d009  Customer Service
# freq       1                 1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         9 non-null      object
#  1   dept_name  9 non-null      object
# dtypes: object(2)
# memory usage: 276.0+ bytes
# None
# id           0
# dept_name    0
# dtype: int64
# Duplicate rows: 0
# Unique departments: 9

# %% [markdown]
# ## Salary Data

# %%
import pandas as pd

dfS = pd.read_csv("salary.csv")
dfS.head()
# Out:
#    employee_id  amount   from_date     to_date
# 0        10001   60117  1986-06-26  1987-06-26
# 1        10001   62102  1987-06-26  1988-06-25
# 2        10001   66074  1988-06-25  1989-06-25
# 3        10001   66596  1989-06-25  1990-06-25
# 4        10001   66961  1990-06-25  1991-06-25

# %%
# 1. Describe (categorical data)
print(dfS.describe(include='object'))

# 2. Info
print(dfS.info())

# 3. Null values
print(dfS.isnull().sum())

# 4. Duplicates
print(f"Duplicate rows: {dfS.duplicated().sum()}")

# 5. Data Validation
print(f"Unique departments: {dfS['employee_id'].nunique()}")
# Out:
#          from_date     to_date
# count      2844047     2844047
# unique        6392        6120
# top     1998-10-25  9999-01-01
# freq          1075      240124
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844047 entries, 0 to 2844046
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   employee_id  int64
#  1   amount       int64
#  2   from_date    object
#  3   to_date      object
# dtypes: int64(2), object(2)
# memory usage: 86.8+ MB
# None
# employee_id    0
# amount         0
# from_date      0
# to_date        0
# dtype: int64
# Duplicate rows: 0
# Unique departments: 300024

# %% [markdown]
# ## Department_manager Data

# %%
import pandas as pd

dfDM = pd.read_csv("department_manager.csv")
dfDM.head()
# Out:
#    employee_id department_id   from_date     to_date
# 0       110022          d001  1985-01-01  1991-10-01
# 1       110039          d001  1991-10-01  9999-01-01
# 2       110085          d002  1985-01-01  1989-12-17
# 3       110114          d002  1989-12-17  9999-01-01
# 4       110183          d003  1985-01-01  1992-03-21

# %%
print(dfDM.describe(include='object'))

# 2. Info
print(dfDM.info())

# 3. Null values
print(dfDM.isnull().sum())

# 4. Duplicates
print(f"Duplicate rows: {dfDM.duplicated().sum()}")

# 5. Data Validation
print(f"Unique departments: {dfDM['department_id'].nunique()}")
print(f"Unique employees: {dfDM['employee_id'].nunique()}")
# Out:
#        department_id   from_date     to_date
# count             24          24          24
# unique             9          16          16
# top             d004  1985-01-01  9999-01-01
# freq               4           9           9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_id    24 non-null     int64
#  1   department_id  24 non-null     object
#  2   from_date      24 non-null     object
#  3   to_date        24 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 900.0+ bytes
# None
# employee_id      0
# department_id    0
# from_date        0
# to_date          0
# dtype: int64
# Duplicate rows: 0
# Unique departments: 9
# Unique employees: 24

# %% [markdown]
# ## Title Data

# %%
import pandas as pd

dfT = pd.read_csv("title.csv")
dfT.head()
# Out:
#    employee_id            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01

# %%
print(dfT.describe(include='object'))
print(dfT.info())
print(dfT.isnull().sum())
print(f"Duplicate rows: {dfT.duplicated().sum()}")
print(f"Unique titles: {dfT['title'].nunique()}")
# Out:
#            title   from_date     to_date
# count     443308      443308      443308
# unique         7        6393        5888
# top     Engineer  1998-10-25  9999-01-01
# freq      115003         132      240124
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   employee_id  443308 non-null  int64
#  1   title        443308 non-null  object
#  2   from_date    443308 non-null  object
#  3   to_date      443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB
# None
# employee_id    0
# title          0
# from_date      0
# to_date        0
# dtype: int64
# Duplicate rows: 0
# Unique titles: 7

# %% [markdown]
# ## Current_employee_snapshot Data

# %%
import pandas as pd

dfCE = pd.read_csv("current_employee_snapshot.csv")
dfCE.head()
# Out:
#    employee_id gender            title  salary_amount           dept_name  \
# 0        10001      M  Senior Engineer          88958         Development
# 1        10005      M     Senior Staff          94692     Human Resources
# 2        10010      F         Engineer          80324  Quality Management
# 3        10013      M     Senior Staff          68901     Human Resources
# 4        10017      F     Senior Staff          99651           Marketing
#
#    salary_percentage_change  company_tenure  title_tenure  department_tenure
# 0                      4.54              20            20                 20
# 1                      3.54              17            10                 17
# 2                      0.93              17            10                  6
# 3                      3.23              21            21                 21
# 4                      1.15              13             6                 13

# %%
print(dfCE.describe(include='object'))
print(dfCE.info())
print(dfCE.isnull().sum())
print(f"Duplicate rows: {dfCE.duplicated().sum()}")
# Out:
#         gender            title    dept_name
# count   240124           240124       240124
# unique       2                7            9
# top          M  Senior Engineer  Development
# freq    144114            85939        61386
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240124 entries, 0 to 240123
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   employee_id               240124 non-null  int64
#  1   gender                    240124 non-null  object
#  2   title                     240124 non-null  object
#  3   salary_amount             240124 non-null  int64
#  4   dept_name                 240124 non-null  object
#  5   salary_percentage_change  240124 non-null  float64
#  6   company_tenure            240124 non-null  int64
#  7   title_tenure              240124 non-null  int64
#  8   department_tenure         240124 non-null  int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 16.5+ MB
# None
# employee_id                 0
# gender                      0
# title                       0
# salary_amount               0
# dept_name                   0
# salary_percentage_change    0
# company_tenure              0
# title_tenure                0
# department_tenure           0
# dtype: int64
# Duplicate rows: 0

# %% [markdown]
# **Cases Study Invistgation.**

# %%
#1."Which departments are best at keeping their employees for many years?"-> Calculate the average employee tenure (years worked) for each department.

'''
average tenure per department using:

employee.csv → employee ID and hire date

department_employee.csv → department history

department.csv → department names
'''

'''
If a department retains employees longer, it might mean:

Good management

Healthy work culture

Better job satisfaction

Employees are more engaged or loyal to the company

'''

# %%
import pandas as pd
from datetime import datetime

# Load and parse dates, handling '9999-01-01'
dfE['hire_date'] = pd.to_datetime(dfE['hire_date'])
dfDE['from_date'] = pd.to_datetime(dfDE['from_date'])
dfDE['to_date'] = dfDE['to_date'].replace('9999-01-01', pd.NaT)
dfDE['to_date'] = pd.to_datetime(dfDE['to_date'])

# Today's date for tenure calculation
today = pd.Timestamp(datetime.today())

# %%
#SQL
# Step 1: Merge employees with their department assignments
emp_dept = pd.merge(dfDE, dfE, left_on='employee_id', right_on='id', how='left')

'''
dfDE: contains department assignments → has employee_id, department_id, from_date, to_date

dfE: contains employee info → has id, hire_date, gender, etc.
'''
# Out:
# '\ndfDE: contains department assignments → has employee_id, department_id, from_date, to_date\n\ndfE: contains employee info → has id, hire_date, gender, etc.\n'

# %%
# Step 2: Calculate employee total tenure (years)
emp_dept['tenure_years'] = (today - emp_dept['hire_date']).dt.days // 365

# Step 3: Use most recent assignment only (to avoid duplication)
emp_dept_latest = emp_dept.sort_values('from_date').drop_duplicates('employee_id', keep='last')

# Step 4: Merge with department names
emp_dept_named = pd.merge(emp_dept_latest, dfD, left_on='department_id', right_on='id', how='left')

# Step 5 (Updated): Group by department and compute both average tenure and employee count
dept_summary = emp_dept_named.groupby('dept_name').agg(
    average_tenure_years=('tenure_years', 'mean'),
    employee_count=('employee_id', 'nunique')
).sort_values(by='average_tenure_years', ascending=False)

# Step 6: Show results
print("\n📊 Department Summary (Average Tenure + Employee Count):")
print(dept_summary)
# Out:
# 📊 Department Summary (Average Tenure + Employee Count):
#                     average_tenure_years  employee_count
# dept_name
# Finance                        35.026831           15579
# Production                     35.022708           66672
# Customer Service               35.022191           21811
# Development                    35.015865           76964
# Sales                          35.013255           46924
# Human Resources                35.002613           16071
# Research                       35.002230           19283
# Quality Management             34.998360           18295
# Marketing                      34.996418           18425

# %%
# Optional: Bar Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
dept_summary.plot(kind='barh', color='steelblue')
plt.title("Average Tenure by Department")
plt.xlabel("Years")
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#2. Find the department with the highest total salary payout (sum of salaries of current employees)?

'''
My steps of thinking to solve this problem?

1:  Merges salary table with employee info to get `hire_date`, etc.
2 : Keeps **only the most recent salary** for each employee.
3 : Merges with their **most recent department** assignment.
4 : Merges to get the **department names**.
5 : Groups by `dept_name` and **sums up salaries**.
6–7: Shows the department with the **highest salary payout**.

'''
# Out:
# '\nMy steps of thinking to solve this problem?\n\n1:  Merges salary table with employee info to get `hire_date`, etc.\n2 : Keeps **only the most recent salary** for each employee.\n3 : Merges with their **most recent department** assignment.\n4 : Merges to get the **department names**.\n5 : Groups by `dept_name` and **sums up salaries**.\n6–7: Shows the department with the **highest salary payout**.\n\n'

# %%
dfS.columns
# Out:
# Index(['employee_id', 'amount', 'from_date', 'to_date'], dtype='object')

# %%
# Step 1: Merge salaries with employee info
emp_salary = pd.merge(dfS, dfE, left_on='employee_id', right_on='id', how='left')

# Step 2: Filter most recent salary entry for each employee
emp_salary_latest = emp_salary.sort_values('to_date').drop_duplicates('employee_id', keep='last')

# Step 3: Merge with latest department assignment
emp_dept_salary = pd.merge(emp_salary_latest, emp_dept_latest, on='employee_id', how='left')

# Step 4: Merge with department names
emp_dept_salary_named = pd.merge(emp_dept_salary, dfD, left_on='department_id', right_on='id', how='left')

# Step 5: Group by department name and sum salaries
dept_salary_total = emp_dept_salary_named.groupby('dept_name')['amount'].sum().sort_values(ascending=False)

# Step 6: Display result
print("\n💰 Total Salary Paid per Department:")
print(dept_salary_total)

# Step 7: Get top department
top_salary_dept = dept_salary_total.idxmax()
top_salary_value = dept_salary_total.max()

print(f"\n🏆 Department with Highest Salary Payout: {top_salary_dept} (${top_salary_value:,.2f})")
# Out:
# 💰 Total Salary Paid per Department:
# dept_name
# Development           5048376854
# Production            4383075277
# Sales                 4072349747
# Marketing             1437916222
# Customer Service      1424112094
# Research              1268654361
# Finance               1191905039
# Quality Management    1159741581
# Human Resources        994028453
# Name: amount, dtype: int64
#
# 🏆 Department with Highest Salary Payout: Development ($5,048,376,854.00)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Reset index to convert Series to DataFrame
dept_salary_total_df = dept_salary_total.reset_index()
dept_salary_total_df.columns = ['Department', 'Total Salary']

# Step 2: Set visual style
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Step 3: Bar plot
sns.barplot(
    data=dept_salary_total_df,
    x='Total Salary',
    y='Department',
    palette='viridis'
)

# Step 4: Add value labels
for index, value in enumerate(dept_salary_total_df['Total Salary']):
    plt.text(value + 1000, index, f"${value:,.0f}", va='center')

# Step 5: Titles and labels
plt.title("💰 Total Salary Paid per Department", fontsize=16)
plt.xlabel("Total Salary (USD)")
plt.ylabel("Department")

# Step 6: Show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_21756\2171839151.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\muham\AppData\Local\Temp\ipykernel_21756\2171839151.py:30: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\muham\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
emp_dept_salary.columns
# Out:
# Index(['employee_id', 'amount', 'from_date_x', 'to_date_x', 'id_x',
#        'birth_date_x', 'first_name_x', 'last_name_x', 'gender_x',
#        'hire_date_x', 'department_id', 'from_date_y', 'to_date_y', 'id_y',
#        'birth_date_y', 'first_name_y', 'last_name_y', 'gender_y',
#        'hire_date_y', 'tenure_years'],
#       dtype='object')

# %%
emp_dept_salary['full_name'] = emp_dept_salary['first_name_x'] + ' ' + emp_dept_salary['last_name_x']

df = emp_dept_salary.merge(dfD, on='department_id', how='left')

df_sorted = df.sort_values(by=['department_id', 'amount'], ascending=[True, False])

top10_per_dept = df_sorted.groupby('department_id').head(10)

cols_to_show = ['department_id', 'dept_name', 'employee_id', 'full_name', 'amount']
result = top10_per_dept[cols_to_show]

print(result)
# Out:
#        department_id         dept_name  employee_id             full_name  \
# 234913          d001         Marketing       466852         Akemi Warwick
# 185338          d001         Marketing        89825          Ingmar Isard
# 279196          d001         Marketing       107140      Ortrud Diderrich
# 236900          d001         Marketing        80937         Chikako Jiang
# 272668          d001         Marketing        51531  Clyde Georgakopoulos
# ...              ...               ...          ...                   ...
# 79338           d009  Customer Service        28337      George Erdmenger
# 94489           d009  Customer Service       235645          Mona Carrere
# 225786          d009  Customer Service        84147          Huan Koshiba
# 210095          d009  Customer Service        74635        Yishai Stanger
# 179191          d009  Customer Service        93414            IEEE Biron
#
#         amount
# 234913  145128
# 185338  143644
# 279196  142506
# 236900  142485
# 272668  141842
# ...        ...
# 79338   138788
# 94489   138637
# 225786  138505
# 210095  137535
# 179191  137436
#
# [90 rows x 5 columns]

# %%
#1.  Top 10 Highest Paid Employees per Department
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 13))
sns.barplot(data=top10_per_dept, x='amount', y='full_name', hue='dept_name', dodge=False)
plt.title('Top 10 Highest Paid Employees per Department')
plt.xlabel('Salary')
plt.ylabel('Employee')
plt.legend(title='Department')
plt.tight_layout()
plt.show()

# %%
#2.  Salary Growth Analysis Over Time

# %%
df['from_date_x'] = pd.to_datetime(df['from_date_x'])
df['year'] = df['from_date_x'].dt.year
avg_salary_by_year = df.groupby('year')['amount'].mean().reset_index()
print(avg_salary_by_year)
# Out:
#     year        amount
# 0   1985  53383.651163
# 1   1986  52889.370297
# 2   1987  55021.931336
# 3   1988  55382.250457
# 4   1989  56514.375956
# 5   1990  57419.984036
# 6   1991  58012.505933
# 7   1992  58344.614583
# 8   1993  59783.167421
# 9   1994  60431.414706
# 10  1995  60894.279684
# 11  1996  61330.920486
# 12  1997  61803.059472
# 13  1998  62174.407117
# 14  1999  62014.095493
# 15  2000  64071.936832
# 16  2001  70711.746950
# 17  2002  72683.788029

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=avg_salary_by_year, x='year', y='amount', marker='o')

plt.title('Average Salary Growth Over Time')
plt.xlabel('Year')
plt.ylabel('Average Salary')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
salary_growth_dept = df.groupby(['dept_name', 'year'])['amount'].mean().reset_index()
salary_growth_dept = salary_growth_dept.sort_values(by=['dept_name', 'year'])


plt.figure(figsize=(14, 7))
sns.lineplot(data=salary_growth_dept, x='year', y='amount', hue='dept_name', marker='o')

plt.title('Salary Growth Over Time by Department')
plt.xlabel('Year')
plt.ylabel('Average Salary')
plt.legend(title='Department', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['from_date_x'] = pd.to_datetime(df['from_date_x'])
df['year'] = df['from_date_x'].dt.year

avg_salary_by_year = df.groupby('year')['amount'].mean().reset_index()

avg_salary_by_year['growth_%'] = avg_salary_by_year['amount'].pct_change() * 100
print(avg_salary_by_year)
# Out:
#     year        amount   growth_%
# 0   1985  53383.651163        NaN
# 1   1986  52889.370297  -0.925903
# 2   1987  55021.931336   4.032117
# 3   1988  55382.250457   0.654865
# 4   1989  56514.375956   2.044203
# 5   1990  57419.984036   1.602438
# 6   1991  58012.505933   1.031909
# 7   1992  58344.614583   0.572478
# 8   1993  59783.167421   2.465614
# 9   1994  60431.414706   1.084331
# 10  1995  60894.279684   0.765934
# 11  1996  61330.920486   0.717047
# 12  1997  61803.059472   0.769822
# 13  1998  62174.407117   0.600856
# 14  1999  62014.095493  -0.257842
# 15  2000  64071.936832   3.318345
# 16  2001  70711.746950  10.363055
# 17  2002  72683.788029   2.788845

# %%
plt.figure(figsize=(10,6))
plt.plot(avg_salary_by_year['year'], avg_salary_by_year['growth_%'], marker='o', color='green')
plt.title('Year-over-Year Salary Growth (%)')
plt.xlabel('Year')
plt.ylabel('Growth Percentage')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#3.  Departments with High Turnover

'''Goal: Identify departments where employees tend to leave (short tenure).

Impact: Red flag for toxic culture or bad management.'''

# %%
df['tenure_years'] = (pd.to_datetime(df['to_date_y']) - pd.to_datetime(df['hire_date_x'])).dt.days / 365

avg_tenure_per_dept = df.groupby(['department_id', 'dept_name'])['tenure_years'].mean().reset_index()

avg_tenure_per_dept = avg_tenure_per_dept.sort_values(by='tenure_years')

print(avg_tenure_per_dept)
# Out:
#   department_id           dept_name  tenure_years
# 2          d003     Human Resources      7.279135
# 0          d001           Marketing      7.311499
# 7          d008            Research      7.316213
# 4          d005         Development      7.316617
# 3          d004          Production      7.361199
# 6          d007               Sales      7.394596
# 5          d006  Quality Management      7.408422
# 1          d002             Finance      7.411538
# 8          d009    Customer Service      7.440243

# %%
short_tenure_df = df[df['tenure_years'] < 2]

short_counts = short_tenure_df.groupby(['department_id', 'dept_name'])['employee_id'].count().reset_index(name='short_term_count')

total_counts = df.groupby(['department_id', 'dept_name'])['employee_id'].count().reset_index(name='total_count')

turnover_df = short_counts.merge(total_counts, on=['department_id', 'dept_name'])
turnover_df['turnover_rate_%'] = (turnover_df['short_term_count'] / turnover_df['total_count']) * 100

turnover_df = turnover_df.sort_values(by='turnover_rate_%', ascending=False)

print(turnover_df)
# Out:
#   department_id           dept_name  short_term_count  total_count  \
# 7          d008            Research               466        19283
# 4          d005         Development              1844        76964
# 2          d003     Human Resources               383        16071
# 3          d004          Production              1545        66672
# 0          d001           Marketing               426        18425
# 1          d002             Finance               351        15579
# 6          d007               Sales              1025        46924
# 5          d006  Quality Management               393        18295
# 8          d009    Customer Service               463        21811
#
#    turnover_rate_%
# 7         2.416636
# 4         2.395925
# 2         2.383175
# 3         2.317315
# 0         2.312076
# 1         2.253033
# 6         2.184383
# 5         2.148128
# 8         2.122782

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=turnover_df, x='dept_name', y='turnover_rate_%', palette='Reds_r')
plt.title('Departments with High Turnover Rate')
plt.ylabel('Turnover Rate (%)')
plt.xlabel('Department')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_21756\1376414580.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=turnover_df, x='dept_name', y='turnover_rate_%', palette='Reds_r')

# %%
df['to_date_y'] = pd.to_datetime(df['to_date_y'])
df['exit_year'] = df['to_date_y'].dt.year
turnover_per_year = df.groupby(['dept_name', 'exit_year'])['employee_id'].nunique().reset_index()
turnover_per_year = turnover_per_year.rename(columns={'employee_id': 'num_employees_left'})
print(turnover_per_year.head(10))
# Out:
#           dept_name  exit_year  num_employees_left
# 0  Customer Service     1985.0                   5
# 1  Customer Service     1986.0                  32
# 2  Customer Service     1987.0                  50
# 3  Customer Service     1988.0                  67
# 4  Customer Service     1989.0                  91
# 5  Customer Service     1990.0                 113
# 6  Customer Service     1991.0                 107
# 7  Customer Service     1992.0                 162
# 8  Customer Service     1993.0                 174
# 9  Customer Service     1994.0                 228

# %%
plt.figure(figsize=(14,7))
sns.lineplot(data=turnover_per_year, x='exit_year', y='num_employees_left', hue='dept_name', marker='o')

plt.title('Number of Employees Who Left Per Year by Department')
plt.xlabel('Year')
plt.ylabel('Employees Left')
plt.legend(title='Department', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
short_tenure_df = df[df['tenure_years'] < 2]

short_counts = short_tenure_df.groupby(['department_id', 'dept_name'])['employee_id'].count().reset_index(name='short_term_count')

total_counts = df.groupby(['department_id', 'dept_name'])['employee_id'].count().reset_index(name='total_count')

turnover_df = short_counts.merge(total_counts, on=['department_id', 'dept_name'], how='right')
turnover_df['short_term_count'] = turnover_df['short_term_count'].fillna(0)  
turnover_df['turnover_rate_%'] = (turnover_df['short_term_count'] / turnover_df['total_count']) * 100

low_turnover = turnover_df.sort_values(by='turnover_rate_%', ascending=True)

print(low_turnover.head(10))
# Out:
#   department_id           dept_name  short_term_count  total_count  \
# 8          d009    Customer Service               463        21811
# 5          d006  Quality Management               393        18295
# 6          d007               Sales              1025        46924
# 1          d002             Finance               351        15579
# 0          d001           Marketing               426        18425
# 3          d004          Production              1545        66672
# 2          d003     Human Resources               383        16071
# 4          d005         Development              1844        76964
# 7          d008            Research               466        19283
#
#    turnover_rate_%
# 8         2.122782
# 5         2.148128
# 6         2.184383
# 1         2.253033
# 0         2.312076
# 3         2.317315
# 2         2.383175
# 4         2.395925
# 7         2.416636

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=low_turnover.head(10), x='dept_name', y='turnover_rate_%', palette='Greens')
plt.title('Departments with Lowest Turnover Rate')
plt.ylabel('Turnover Rate (%)')
plt.xlabel('Department')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_21756\1799866781.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=low_turnover.head(10), x='dept_name', y='turnover_rate_%', palette='Greens')
